# %%
n0 = 1.37
n1 = -0.01
n3 = 0.04
n4 = -0.01

n = lambda z,h: n0 + n1*h^2 + n3*z + n4*z^2


contour_plot(n,(-10,10),(-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
solve(x^2 -1 == 0)
# Out:
# [x == -1, x == 1]

# %%
integrate(x^3 + 2*x^2, x)
# Out:
# 1/4*x^4 + 2/3*x^3
